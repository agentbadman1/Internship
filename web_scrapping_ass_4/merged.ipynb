# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
driver.maximize_window()

# %%
rank = []
name = []
artist = []
upload_date = []
views = []

# %%
from selenium.common.exceptions import NoSuchElementException

# %%
try:
    rank_tag = driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[1]')
    for i in rank_tag[0:30]:
        j = i.text
        rank.append(j)
except NoSuchElementException as e:
    rank.append("-")

# %%
try:
    name_tag = driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[2]')
    for i in name_tag[0:30]:
        j = i.text
        name.append(j)
except NoSuchElementException as e:
    name.append("-")

# %%
try:
    artist_tag = driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[3]')
    for i in artist_tag[0:30]:
        j = i.text
        artist.append(j)
except NoSuchElementException as e:
    artist.append("-")

# %%
try:
    upload_date_tag = driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[5]')
    for i in upload_date_tag[0:30]:
        j = i.text
        upload_date.append(j)
except NoSuchElementException as e:
    upload_date.append("-")

# %%
try:
    views_tag = driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[4]')
    for i in views_tag[0:30]:
        j = i.text
        views.append(j)
except NoSuchElementException as e:
    views.append("-")

# %%
len(name),len(rank),len(artist),len(upload_date),len(views)
# Out:
# (30, 30, 30, 30, 30)

# %%
data = pd.DataFrame({"RANK":rank,"NAME":name,
                    "ARTIST":artist,"UPLOAD DATE":upload_date,
                    "VIEWS":views})

# %%
data
# Out:
#    RANK                                             NAME  \
# 0    1.                            "Baby Shark Dance"[4]
# 1    2.                                   "Despacito"[7]
# 2    3.                       "Johny Johny Yes Papa"[14]
# 3    4.                                  "Bath Song"[15]
# 4    5.                               "Shape of You"[16]
# 5    6.                              "See You Again"[18]
# 6    7.                "Phonics Song with Two Words"[23]
# 7    8.                          "Wheels on the Bus"[24]
# 8    9.                                "Uptown Funk"[25]
# 9   10.  "Learning Colors – Colorful Eggs on a Farm"[26]
# 10  11.                              "Gangnam Style"[27]
# 11  12.   "Masha and the Bear – Recipe for Disaster"[32]
# 12  13.                             "Dame Tu Cosita"[33]
# 13  14.                                      "Sugar"[34]
# 14  15.                                       "Roar"[35]
# ...

# %%
driver.get("https://www.bcci.tv/")

# %%
driver.maximize_window()

# %%
inte = driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a')
inte.click()

# %%
fix = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[2]/div/div[1]/div/div[1]')
fix.click()

# %%
men = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[2]/div/div[1]/div/div[2]/div[2]')
men.click()

# %%
from selenium.common.exceptions import NoSuchElementException

# %%
title = []
series = []
place = []
date = []
time = []

# %%
try:
    title_tag = driver.find_elements(By.XPATH,'//span[@class="matchOrderText ng-binding ng-scope"]')
    for i in title_tag:
        j = i.text.split(" -")[0]
        title.append(j)
except NoSuchElementException as e:
    title.append("-")

# %%
try:
    series_tag = driver.find_elements(By.XPATH,'//span[@class="ng-binding"]')
    for i in series_tag:
        j = i.text
        series.append(j)
except NoSuchElementException as e:
    series.append("-")

# %%
try:
    place_tag = driver.find_elements(By.XPATH,'//div[@class="fix-place ng-binding ng-scope"]')
    for i in place_tag:
        j = i.text.split(" - ")[1]
        place.append(j)
except NoSuchElementException as e:
    place.append("-")

# %%
try:
    date_tag = driver.find_elements(By.XPATH,'//h5[@class="ng-binding"]')
    for i in date_tag:
        j = i.text
        date.append(j)
except NoSuchElementException as e:
    date.append("-")

# %%
try:
    time_tag = driver.find_elements(By.XPATH,'//h5[@class="text-right ng-binding"]')
    for i in time_tag:
        j = i.text
        time.append(j)
except NoSuchElementException as e:
    time.append("-")

# %%
data = pd.DataFrame({"TITLE":title,"Series":series,
                    "PLACE":place,"DATE":date,
                    "TIME":time})

# %%
data
# Out:
#       TITLE                                        Series  \
# 0  3rd T20I  NEW ZEALAND TOUR OF INDIA T20 SERIES 2022-23
# 1  1st Test   AUSTRALIA TOUR OF INDIA TEST SERIES 2022-23
# 2  2nd Test   AUSTRALIA TOUR OF INDIA TEST SERIES 2022-23
# 3  3rd Test   AUSTRALIA TOUR OF INDIA TEST SERIES 2022-23
# 4  4th Test   AUSTRALIA TOUR OF INDIA TEST SERIES 2022-23
# 5   1st ODI    AUSTRALIA TOUR OF INDIA ODI SERIES 2022-23
# 6   2nd ODI    AUSTRALIA TOUR OF INDIA ODI SERIES 2022-23
# 7   3rd ODI    AUSTRALIA TOUR OF INDIA ODI SERIES 2022-23
#
#                                                PLACE         DATE         TIME
# 0                   Narendra Modi Stadium, Ahmedabad   1 FEB 2023  7:00 PM IST
# 1       Vidarbha Cricket Association Stadium, Nagpur   9 FEB 2023  9:30 AM IST
# 2                        Arun Jaitley Stadium, Delhi  17 FEB 2023  9:30 AM IST
# 3  Himachal Pradesh Cricket Association Stadium, ...   1 MAR 2023  9:30 AM IST
# ...

# %%
driver.get("https://www.statisticstimes.com/economy/india-statistics.php")

# %%
gdp = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]')
gdp.click()

# %%
rank = []
state = []
gsdp18_19 = []
gsdp19_20 = []
share = []
gdp = []

# %%
try:
    rank_tag = driver.find_elements(By.XPATH,'//div[@class="dataTables_wrapper"]/table/tbody/tr/td[1]')
    for i in rank_tag[0:33]:
        j = i.text
        rank.append(j)
except NoSuchElementException as e:
    rank.append("-")

# %%
try:
    state_tag = driver.find_elements(By.XPATH,'//div[@class="dataTables_wrapper"]/table/tbody/tr/td[2]')
    for i in state_tag[0:33]:
        j = i.text
        state.append(j)
except NoSuchElementException as e:
    state.append("-")

# %%
try:
    gsdp18_19_tag = driver.find_elements(By.XPATH,'//div[@class="dataTables_wrapper"]/table/tbody/tr/td[4]')
    for i in gsdp18_19_tag[0:33]:
        j = i.text
        gsdp18_19.append(j)
except NoSuchElementException as e:
    gsdp18_19.append("-")

# %%
try:
    gsdp19_20_tag = driver.find_elements(By.XPATH,'//div[@class="dataTables_wrapper"]/table/tbody/tr/td[3]')
    for i in gsdp19_20_tag[0:33]:
        j = i.text
        gsdp19_20.append(j)
except NoSuchElementException as e:
    gsdp19_20.append("-")

# %%
try:
    share_tag = driver.find_elements(By.XPATH,'//div[@class="dataTables_wrapper"]/table/tbody/tr/td[5]')
    for i in share_tag[0:33]:
        j = i.text
        share.append(j)
except NoSuchElementException as e:
    share.append("-")

# %%
try:
    gdp_tag = driver.find_elements(By.XPATH,'//div[@class="dataTables_wrapper"]/table/tbody/tr/td[6]')
    for i in gdp_tag[0:33]:
        j = i.text
        gdp.append(j)
except NoSuchElementException as e:
    gdp.append("-")

# %%
data = pd.DataFrame({"RANK":rank,"STATE":state,
                    "GSDP 18-19":gsdp18_19,"GSDP 19-20":gsdp19_20,
                    "SHARE":share,"GDP":gdp})

# %%
data
# Out:
#    RANK                      STATE GSDP 18-19 GSDP 19-20   SHARE      GDP
# 0     1                Maharashtra  2,632,792          -  13.94%  399.921
# 1     2                 Tamil Nadu  1,630,208  1,845,853   8.63%  247.629
# 2     3              Uttar Pradesh  1,584,764  1,687,818   8.39%  240.726
# 3     4                    Gujarat  1,502,899          -   7.96%  228.290
# 4     5                  Karnataka  1,493,127  1,631,977   7.91%  226.806
# 5     6                West Bengal  1,089,898  1,253,832   5.77%  165.556
# 6     7                  Rajasthan    942,586  1,020,989   4.99%  143.179
# 7     8             Andhra Pradesh    862,957    972,782   4.57%  131.083
# 8     9                  Telangana    861,031    969,604   4.56%  130.791
# 9    10             Madhya Pradesh    809,592    906,672   4.29%  122.977
# 10   11                     Kerala    781,653          -   4.14%  118.733
# 11   12                      Delhi    774,870    856,112   4.10%  117.703
# ...

# %%
driver.get(r'https://github.com/')

# %%
aa = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button')
aa.click()

# %%
bb = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]')
bb.click()

# %%
title = []
desc = []
count = []
language = []
asd = []

# %%
try:
    title_tag = driver.find_elements(By.XPATH,'//h1[@class="h3 lh-condensed"]')
    for i in title_tag[0:23]:
        j = i.text
        title.append(j)
except NoSuchElementException as e:
    title.append("-")

# %%
try:
    desc_tag = driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
    for i in desc_tag[0:23]:
        j = i.text
        desc.append(j)
except NoSuchElementException as e:
    desc.append("-")

# %%
try:
    asd_tag = driver.find_elements(By.XPATH,'//a[@class="Link--muted d-inline-block mr-3"]')
    for i in asd_tag[0:46]:
        j = i.text
        asd.append(j)
except NoSuchElementException as e:
    asd.append("-")

# %%
for i in asd:
    if asd.index(i) %2 !=0:
        count.append(i)

# %%
try:
    lang_tag = driver.find_elements(By.XPATH,'//span[@class="d-inline-block ml-0 mr-3"]')
    for i in lang_tag[0:23]:
        j = i.text
        language.append(j)
except NoSuchElementException as e:
    language.append("-")

# %%
data = pd.DataFrame({"TITLE":title,"DESCRIPTION":desc,
                    "COUNT":count,"LANGAUGE":language})

# %%
data
# Out:
#                                             TITLE  \
# 0                               fathyb / carbonyl
# 1                           localsend / localsend
# 2                 bregman-arie / devops-exercises
# 3                      521xueweihan / HelloGitHub
# 4                               mindsdb / mindsdb
# 5              codecrafters-io / build-your-own-x
# 6                   AzeemIdrisi / PhoneSploit-Pro
# 7                          Snailclimb / JavaGuide
# 8    practical-tutorials / project-based-learning
# 9                      AabyssZG / SpringBoot-Scan
# 10                   lucidrains / musiclm-pytorch
# 11                      LAION-AI / Open-Assistant
# 12  MaaAssistantArknights / MaaAssistantArknights
# 13                                 apache / dubbo
# 14                     hwchase17 / chat-langchain
# 15                              cxasm / notepad--
# 16                            Z4nzu / hackingtool
# 17                         showlab / Tune-A-Video
# ...

# %%
driver.get(r'https://www.billboard.com/')

# %%
button = driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[4]/div/div[1]/div[1]/button')
button.click()

# %%
bb = driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div/div/div/ul/li[1]/h3/a')
bb.click()

# %%
cc = driver.find_element(By.XPATH,'/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[1]/div/div[2]/span/a')
cc.click()

# %%
song = []
artist = []
lw = []
pr = []
wob = []
add = []

# %%
try:
    song_tag = driver.find_elements(By.XPATH,'//h3[@class="c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 u-font-size-23@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-245 u-max-width-230@tablet-only u-letter-spacing-0028@tablet"]')
    for i in song_tag:
        j = i.text
        song.append(j)
except NoSuchElementException as e:
    song.append("-")

# %%
try:
    song_tag = driver.find_elements(By.XPATH,'//h3[@class="c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only"]')
    for i in song_tag:
        j = i.text
        song.append(j)
except NoSuchElementException as e:
    song.append("-")

# %%
try:
    artist_tag = driver.find_elements(By.XPATH,'//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet"]')
    for i in artist_tag:
        j = i.text
        artist.append(j)
except NoSuchElementException as e:
    artist.append("-")

# %%
try:
    artist_tag = driver.find_elements(By.XPATH,'//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"]')
    for i in artist_tag:
        j = i.text
        artist.append(j)
except NoSuchElementException as e:
    artist.append("-")

# %%
try:
    lw_tag = driver.find_elements(By.XPATH,'//span[@class="c-label  a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet"]')
    for i in lw_tag[0:1]:
        j = i.text
        lw.append(j)
except NoSuchElementException as e:
    lw.append("-")

# %%
try:
    pr_tag = driver.find_elements(By.XPATH,'//span[@class="c-label  a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet"]')
    for i in pr_tag[1:2]:
        j = i.text
        pr.append(j)
except NoSuchElementException as e:
    pr.append("-")

# %%
pr
# Out:
# ['1']

# %%
try:
    wob_tag = driver.find_elements(By.XPATH,'//span[@class="c-label  a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet"]')
    for i in wob_tag[2:3]:
        j = i.text
        wob.append(j)
except NoSuchElementException as e:
    wob.append("-")

# %%
wob
# Out:
# ['2']

# %%
try:
    add_tag = driver.find_elements(By.XPATH,'//span[@class="c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max"]')
    for i in add_tag:
        j = i.text
        if len(j) != 0:
            add.append(j)
except NoSuchElementException as e:
    add.append("-")

# %%
lw = add[::3]
pr = add[1::3]
wob = add[2::3]

# %%
lw.insert(0,"1")
pr.insert(0,"1")
wob.insert(0,"2")

# %%
data = pd.DataFrame({"SONG":song,"ARTIST":artist,
                    "LAST WEEK RANK":lw,"PEAK RANK":pr,
                    "WEEK ON CAHRT":wob})

# %%
data
# Out:
#                 SONG                                ARTIST LAST WEEK RANK  \
# 0            Flowers                           Miley Cyrus              1
# 1          Kill Bill                                   SZA              2
# 2          Anti-Hero                          Taylor Swift              3
# 3           Creepin'  Metro Boomin, The Weeknd & 21 Savage              4
# 4             Unholy                Sam Smith & Kim Petras              5
# ..               ...                                   ...            ...
# 95       Do It Again                    NLE Choppa & 2Rare              -
# 96          Miss You            Oliver Tree & Robin Schulz             96
# 97          Back End                         Finesse2Tymes              -
# 98         Open Arms            SZA Featuring Travis Scott             89
# 99  Spit In My Face!                              ThxSoMch              -
#
#    PEAK RANK WEEK ON CAHRT
# 0          1             2
# ...

# %%
driver.get(r'https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
name = []
author = []
volume = []
pub = []
genre = []

# %%
try:
    name_tag = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[2]')
    for i in name_tag:
        j = i.text
        name.append(j)
except NoSuchElementException as e:
    name.append("-")

# %%
len(name)
# Out:
# 100

# %%
try:
    author_tag = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[3]')
    for i in author_tag:
        j = i.text
        author.append(j)
except NoSuchElementException as e:
    author.append("-")

# %%
try:
    volume_tag = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[4]')
    for i in volume_tag:
        j = i.text
        volume.append(j)
except NoSuchElementException as e:
    volume.append("-")

# %%
try:
    pub_tag = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[5]')
    for i in pub_tag:
        j = i.text
        pub.append(j)
except NoSuchElementException as e:
    pub.append("-")

# %%
try:
    genre_tag = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[6]')
    for i in genre_tag:
        j = i.text
        genre.append(j)
except NoSuchElementException as e:
    genre.append("-")

# %%
data = pd.DataFrame({"TITLE":name,"AUTHOR":author,
                    "VOLUME SOLD":volume,"PUBLICATION":pub,
                    "GENRE":genre})

# %%
data
# Out:
#                                                 TITLE            AUTHOR  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    VOLUME SOLD      PUBLICATION                        GENRE
# ...

# %%
driver.get(r'https://www.imdb.com/list/ls095964455/')

# %%
name = []
year = []
genre = []
time = []
rating = []
vote = []
xd = []
vote2 = []

# %%
try:
    name_tag = driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]')
    for i in name_tag:
        j = i.text.split(". ")[1].split(" (")[0]
        name.append(j)
except NoSuchElementException as e:
    name.append("-")

# %%
try:
    year_tag = driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]')
    for i in year_tag:
        j = i.text.split(" (")[1].split(")")[0]
        year.append(j)
except NoSuchElementException as e:
    year.append("-")

# %%
try:
    genre_tag = driver.find_elements(By.XPATH,'//span[@class="genre"]')
    for i in genre_tag:
        j = i.text
        genre.append(j)
except NoSuchElementException as e:
    genre.append("-")

# %%
try:
    time_tag = driver.find_elements(By.XPATH,'//span[@class="runtime"]')
    for i in time_tag:
        j = i.text
        time.append(j)
except NoSuchElementException as e:
    time.append("-")

# %%
try:
    rating_tag = driver.find_elements(By.XPATH,'//div[@class="ipl-rating-star small"]')
    for i in rating_tag:
        j = i.text
        rating.append(j)
except NoSuchElementException as e:
    rating.append("-")

# %%
try:
    xd_tag = driver.find_elements(By.XPATH,'//p[@class="text-muted text-small"]')
    for i in xd_tag:
        j = i.text
        xd.append(j)
except NoSuchElementException as e:
    xd.append("-")

# %%
vote = xd[2::3]

# %%
for i in vote:
    j = i.split(": ")[1]
    vote2.append(j)

# %%
data = pd.DataFrame({"TITLE":name,"YEAR SPAN":year,
                    "GENRE":genre,"RUN TIME":time,
                    "RATING":rating,"VOTES":vote2})

# %%
data
# Out:
#                              TITLE  YEAR SPAN                     GENRE  \
# 0                  Game of Thrones  2011–2019  Action, Adventure, Drama
# 1                  Stranger Things     2016–     Drama, Fantasy, Horror
# 2                 The Walking Dead  2010–2022   Drama, Horror, Thriller
# 3                   13 Reasons Why  2017–2020  Drama, Mystery, Thriller
# 4                          The 100  2014–2020    Drama, Mystery, Sci-Fi
# ..                             ...        ...                       ...
# 95                           Reign  2013–2017                     Drama
# 96  A Series of Unfortunate Events  2017–2019  Adventure, Comedy, Drama
# 97                  Criminal Minds     2005–      Crime, Drama, Mystery
# 98           Scream: The TV Series  2015–2019      Comedy, Crime, Drama
# 99      The Haunting of Hill House       2018    Drama, Horror, Mystery
#
#    RUN TIME RATING      VOTES
# 0    57 min    9.2  2,117,162
# 1    51 min    8.7  1,206,362
# ...

# %%
driver.get(r'https://archive.ics.uci.edu/ml/index.php')

# %%
aa = driver.find_element(By.XPATH,'/html/body/table[1]/tbody/tr/td[2]/span[2]')
aa.click()

# %%
name = []
datatype = []
task = []
att = []
inst = []
atta = []
year = []
alld = []

# %%
try:
    alld_tag = driver.find_elements(By.XPATH,'//p[@class="normal"]')
    for i in alld_tag[8:4362]:
        j = i.text
        alld.append(j)
except NoSuchElementException as e:
    alld.append("-")

# %%
name = alld[::7]
datatype = alld[1::7]
task = alld[2::7]
att = alld[3::7]
inst = alld[4::7]
atta =alld[5::7]
year = alld[6::7]

# %%
len(name),len(datatype),len(task),len(att),len(inst),len(atta),len(year)
# Out:
# (622, 622, 622, 622, 622, 622, 622)

# %%
data = pd.DataFrame({"DATASET NAME":name,"DATASET TYPE":datatype,
                    "TASK":task,"ATTRIBUTE TYPE":att,
                    "NO FO INSTANCES":inst,"NO OF ATTRIBUTES":atta,
                    "YEAR":year})

# %%
data
# Out:
#                                           DATASET NAME  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                    DATASET TYPE                  TASK  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...
