# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-red-64-gb/product-reviews/itmc3935326f2feb?pid=MOBFWQ6BYYV3FCU7&lid=LSTMOBFWQ6BYYV3FCU7ZCY7Y9&marketplace=FLIPKART")

# %%
rating = []
rs = []
fr = []

# %%
for i in range(0,10):
    if i==0:
        rating_tag = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
        for j in rating_tag:
            rr = j.text
            rating.append(rr)
        
        rs_tag = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
        for d in rs_tag:
            rst = d.text
            rs.append(rst)
    
        fr_tag = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
        for w in fr_tag:
            frt = w.text
            fr.append(frt)
            
    if i==1:
        driver = webdriver.Chrome(r"chromedriver.exe")
        driver.get("https://www.flipkart.com/apple-iphone-11-red-64-gb/product-reviews/itmc3935326f2feb?pid=MOBFWQ6BYYV3FCU7&lid=LSTMOBFWQ6BYYV3FCU7ZCY7Y9&marketplace=FLIPKART&page=2")
        for j in rating_tag:
            rr = j.text
            rating.append(rr)
        
        rs_tag = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
        for d in rs_tag:
            rst = d.text
            rs.append(rst)
    
        fr_tag = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
        for w in fr_tag:
            frt = w.text
            fr.append(frt)
            
    if i==2:
        driver = webdriver.Chrome(r"chromedriver.exe")
        driver.get("https://www.flipkart.com/apple-iphone-11-red-64-gb/product-reviews/itmc3935326f2feb?pid=MOBFWQ6BYYV3FCU7&lid=LSTMOBFWQ6BYYV3FCU7ZCY7Y9&marketplace=FLIPKART&page=3")
        for j in rating_tag:
            rr = j.text
            rating.append(rr)
        
        rs_tag = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
        for d in rs_tag:
            rst = d.text
            rs.append(rst)
    
        fr_tag = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
        for w in fr_tag:
            frt = w.text
            fr.append(frt)
            
    if i==3:
        driver = webdriver.Chrome(r"chromedriver.exe")
        driver.get("https://www.flipkart.com/apple-iphone-11-red-64-gb/product-reviews/itmc3935326f2feb?pid=MOBFWQ6BYYV3FCU7&lid=LSTMOBFWQ6BYYV3FCU7ZCY7Y9&marketplace=FLIPKART&page=4")
        for j in rating_tag:
            rr = j.text
            rating.append(rr)
        
        rs_tag = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
        for d in rs_tag:
            rst = d.text
            rs.append(rst)
    
        fr_tag = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
        for w in fr_tag:
            frt = w.text
            fr.append(frt)
            
    if i==4:
        driver = webdriver.Chrome(r"chromedriver.exe")
        driver.get("https://www.flipkart.com/apple-iphone-11-red-64-gb/product-reviews/itmc3935326f2feb?pid=MOBFWQ6BYYV3FCU7&lid=LSTMOBFWQ6BYYV3FCU7ZCY7Y9&marketplace=FLIPKART&page=5")
        for j in rating_tag:
            rr = j.text
            rating.append(rr)
        
        rs_tag = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
        for d in rs_tag:
            rst = d.text
            rs.append(rst)
    
        fr_tag = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
        for w in fr_tag:
            frt = w.text
            fr.append(frt)
            
    if i==5:
        driver = webdriver.Chrome(r"chromedriver.exe")
        driver.get("https://www.flipkart.com/apple-iphone-11-red-64-gb/product-reviews/itmc3935326f2feb?pid=MOBFWQ6BYYV3FCU7&lid=LSTMOBFWQ6BYYV3FCU7ZCY7Y9&marketplace=FLIPKART&page=6")
        for j in rating_tag:
            rr = j.text
            rating.append(rr)
        
        rs_tag = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
        for d in rs_tag:
            rst = d.text
            rs.append(rst)
    
        fr_tag = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
        for w in fr_tag:
            frt = w.text
            fr.append(frt)
            
    if i==6:
        driver = webdriver.Chrome(r"chromedriver.exe")
        driver.get("https://www.flipkart.com/apple-iphone-11-red-64-gb/product-reviews/itmc3935326f2feb?pid=MOBFWQ6BYYV3FCU7&lid=LSTMOBFWQ6BYYV3FCU7ZCY7Y9&marketplace=FLIPKART&page=7")
        for j in rating_tag:
            rr = j.text
            rating.append(rr)
        
        rs_tag = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
        for d in rs_tag:
            rst = d.text
            rs.append(rst)
    
        fr_tag = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
        for w in fr_tag:
            frt = w.text
            fr.append(frt)
            
    if i==7:
        driver = webdriver.Chrome(r"chromedriver.exe")
        driver.get("https://www.flipkart.com/apple-iphone-11-red-64-gb/product-reviews/itmc3935326f2feb?pid=MOBFWQ6BYYV3FCU7&lid=LSTMOBFWQ6BYYV3FCU7ZCY7Y9&marketplace=FLIPKART&page=8")
        for j in rating_tag:
            rr = j.text
            rating.append(rr)
        
        rs_tag = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
        for d in rs_tag:
            rst = d.text
            rs.append(rst)
    
        fr_tag = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
        for w in fr_tag:
            frt = w.text
            fr.append(frt)
            
    if i ==8:
        driver = webdriver.Chrome(r"chromedriver.exe")
        driver.get("https://www.flipkart.com/apple-iphone-11-red-64-gb/product-reviews/itmc3935326f2feb?pid=MOBFWQ6BYYV3FCU7&lid=LSTMOBFWQ6BYYV3FCU7ZCY7Y9&marketplace=FLIPKART&page=9")
        for j in rating_tag:
            rr = j.text
            rating.append(rr)
        
        rs_tag = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
        for d in rs_tag:
            rst = d.text
            rs.append(rst)
    
        fr_tag = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
        for w in fr_tag:
            frt = w.text
            fr.append(frt)
            
    if i==9:
        driver = webdriver.Chrome(r"chromedriver.exe")
        driver.get("https://www.flipkart.com/apple-iphone-11-red-64-gb/product-reviews/itmc3935326f2feb?pid=MOBFWQ6BYYV3FCU7&lid=LSTMOBFWQ6BYYV3FCU7ZCY7Y9&marketplace=FLIPKART&page=10")
        for j in rating_tag:
            rr = j.text
            rating.append(rr)
        
        rs_tag = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
        for d in rs_tag:
            rst = d.text
            rs.append(rst)
    
        fr_tag = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
        for w in fr_tag:
            frt = w.text
            fr.append(frt)

# %%
data = pd.DataFrame({"Rating":rating,"Review SUmmary":rs,"Detailed Summary":fr})

# %%
data
# Out:
#    Rating       Review SUmmary  \
# 0       5       Simply awesome
# 1       5     Perfect product!
# 2       5  Best in the market!
# 3       4      Value-for-money
# 4       5   Highly recommended
# ..    ...                  ...
# 95      5            Wonderful
# 96      5             Terrific
# 97      5  Best in the market!
# 98      5     Perfect product!
# 99      5    Absolute rubbish!
#
#                                      Detailed Summary
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   I'm Really happy with the product\nDelivery wa...
# 4   It's my first time to use iOS phone and I am l...
# ..                                                ...
# 95  Its good.. a little heavy on my pinky but its ...
# 96  Simply Awesome\n\nI have upgraded from iPhone ...
# 97  Damn this phone is a blast . Upgraded from and...
# ...
